# %% [markdown]
# prediction with trained ann model

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import pickle
import pandas as pd 
import numpy as np

# %%
## load the trained model, scalar pickle, onehot
from tensorflow.keras.models import load_model
model = load_model('model.h5')

#load the encoder and scaler
with open('onehot_encoder_geo.pkl','rb') as file:
    label_encoder_geo = pickle.load(file)

with open('label_encoder_gender.pkl','rb') as file:
    label_encoder_gender = pickle.load(file)

with open('scaler.pkl','rb') as file:
    scaler = pickle.load(file)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# giving an example input data
input_data = {
    'CreditScore': 600,
    'Geography': 'France',
    'Gender': 'Male',
    'Age': 40,
    'Tenure': 3,
    'Balance': 60000,
    'NumOfProducts': 2,
    'HasCrCard': 1,
    'IsActiveMember': 1,
    'EstimatedSalary': 50000
}

# %%
#one hotencode geography
geo_encoded = label_encoder_geo.transform([[input_data['Geography']]]).toarray()
geo_encoded_df = pd.DataFrame(geo_encoded, columns=label_encoder_geo.get_feature_names_out(['Geography']))
geo_encoded_df
# Out:
# c:\Users\febaj\Downloads\DEEP LEARNING_ann\churn\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
#    Geography_France  Geography_Germany  Geography_Spain
# 0               1.0                0.0              0.0

# %%
input_df = pd.DataFrame([input_data])
input_df
# Out:
#    CreditScore Geography Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          600    France   Male   40       3    60000              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1            50000

# %%
## encode categoricl variables
input_df['Gender']=label_encoder_gender.transform(input_df['Gender'])
input_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 ## encode categoricl variables
# ----> 2 input_df['Gender']=label_encoder_gender.transform(input_df['Gender'])
#       3 input_df
#
# File c:\Users\febaj\Downloads\DEEP LEARNING_ann\churn\Lib\site-packages\sklearn\preprocessing\_label.py:129, in LabelEncoder.transform(self, y)
#     127 check_is_fitted(self)
#     128 xp, _ = get_namespace(y)
# --> 129 y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
#     130 # transform of empty array is empty array
#     131 if _num_samples(y) == 0:
#
# File c:\Users\febaj\Downloads\DEEP LEARNING_ann\churn\Lib\site-packages\sklearn\utils\validation.py:1456, in column_or_1d(y, dtype, warn, device)
#    1418 """Ravel column or 1d numpy array, else raises an error.
#    1419
#    1420 Parameters
#    (...)
#    1453 array([1, 1])
#    1454 """
#    1455 xp, _ = get_namespace(y)
# -> 1456 y = check_array(
#    1457     y,
#    1458     ensure_2d=False,
#    1459     dtype=dtype,
#    1460     input_name="y",
#    1461     ensure_all_finite=False,
#    1462     ensure_min_samples=0,
#    1463 )
#    1465 shape = y.shape
#    1466 if len(shape) == 1:
#
# File c:\Users\febaj\Downloads\DEEP LEARNING_ann\churn\Lib\site-packages\sklearn\utils\validation.py:1053, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1045     if xp.isdtype(array.dtype, ("real floating", "complex floating")):
#    1046         _assert_all_finite(
#    1047             array,
#    1048             allow_nan=False,
#    (...)
#    1051             input_name=input_name,
#    1052         )
# -> 1053     array = xp.astype(array, dtype, copy=False)
#    1054 else:
#    1055     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#
# File c:\Users\febaj\Downloads\DEEP LEARNING_ann\churn\Lib\site-packages\sklearn\utils\_array_api.py:399, in _NumPyAPIWrapper.astype(self, x, dtype, copy, casting)
#     397 def astype(self, x, dtype, *, copy=True, casting="unsafe"):
#     398     # astype is not defined in the top level NumPy namespace
# --> 399     return x.astype(dtype, copy=copy, casting=casting)
#
# ValueError: invalid literal for int() with base 10: 'Male'

# %%
#concatenate one hot encoded
input_df = pd.concat([input_df.drop("Geography",axis=1),geo_encoded_df],axis=1)
input_df
# Out:
#    CreditScore Gender  Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# 0          600   Male   40       3    60000              2          1
#
#    IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0               1            50000               1.0                0.0
#
#    Geography_Spain
# 0              0.0
